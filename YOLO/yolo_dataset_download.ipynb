# %%
import os
from dotenv import load_dotenv
from roboflow import Roboflow

load_dotenv()
api_key = os.getenv("ROBOFLOW_API_KEY")

def download_dataset():
    rf = Roboflow(api_key=api_key)
    project = rf.workspace("hemorrhagesegmentation").project("tp26_detection")
    version = project.version(1)
    dataset = version.download("yolov11")

    return dataset, version, project

# %%
dataset, version, project = download_dataset()

print(dataset)
print(version)
print(project)

print(dataset.location)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in TP26_detection-1 to yolov11:: 100%|██████████| 11658/11658 [00:01<00:00, 6628.27it/s]
# Extracting Dataset Version Zip to TP26_detection-1 in yolov11:: 100%|██████████| 1072/1072 [00:00<00:00, 1851.42it/s]
# <roboflow.core.dataset.Dataset object at 0x000002C789D6F0E0>
# {
#   "name": "TP26_detection",
#   "type": "object-detection",
#   "version": "1",
#   "augmentation": {},
#   "created": 1773778935.861,
#   "preprocessing": {},
#   "splits": {
#     "valid": 104,
#     "test": 111,
#     "train": 315
#   },
#   "workspace": "hemorrhagesegmentation"
# }
# {
#   "name": "TP26_detection",
#   "type": "object-detection",
#   "workspace": "hemorrhagesegmentation"
# }
# C:\Users\benko\OneDrive\Počítač\YOLO\TP26_detection-1
