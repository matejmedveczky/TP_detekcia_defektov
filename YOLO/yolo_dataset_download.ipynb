# %%
import os
from dotenv import load_dotenv
from roboflow import Roboflow
from sympy import rf

load_dotenv()
api_key = os.getenv("ROBOFLOW_API_KEY")

def download_dataset():
    rf = Roboflow(api_key=api_key)
    project = rf.workspace("hemorrhagesegmentation").project("tp26_plastic_v1")
    version = project.version(3)
    dataset = version.download("yolov11")

    return dataset, version, project

# %%
dataset, version, project = download_dataset()

print(dataset)
print(version)
print(project)

print(dataset.location)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in TP26_plastic_v1-3 to yolov11:: 100%|██████████| 26498/26498 [00:26<00:00, 1007.77it/s]
# Extracting Dataset Version Zip to TP26_plastic_v1-3 in yolov11:: 100%|██████████| 2783/2783 [00:03<00:00, 820.24it/s]
# <roboflow.core.dataset.Dataset object at 0x000002B02AD65450>
# {
#   "name": "TP26_plastic_v1",
#   "type": "object-detection",
#   "version": "3",
#   "augmentation": {
#     "flip": {
#       "horizontal": true,
#       "vertical": true
#     },
#     "blur": {
#       "pixels": 0.5
#     },
#     "brightness": {
#       "percent": 15,
#       "brighten": true,
#       "darken": true
#     },
#     "image": {
#       "versions": 2
#     }
#   },
#   "created": 1778074636.821,
#   "preprocessing": {
#     "auto-orient": true
#   },
#   "splits": {
#     "valid": 123,
#     "test": 122,
#     "train": 1144
#   },
#   "workspace": "hemorrhagesegmentation"
# }
# {
#   "name": "TP26_plastic_v1",
#   "type": "object-detection",
#   "workspace": "hemorrhagesegmentation"
# }
# c:\Users\matej\OneDrive\Dokumenty\STU FEI\Ing\TP\YOLO\TP26_plastic_v1-3
