# %%
import os
from dotenv import load_dotenv
from roboflow import Roboflow

load_dotenv()
api_key = os.getenv("ROBOFLOW_API_KEY")

def download_dataset():
    rf = Roboflow(api_key=api_key)
    project = rf.workspace("hemorrhagesegmentation").project("tp26_detection_v2")
    version = project.version(1)
    dataset = version.download("yolov11")

    return dataset, version, project

# %%
dataset, version, project = download_dataset()

print(dataset)
print(version)
print(project)

print(dataset.location)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in TP26_detection_v2-1 to yolov11:: 100%|██████████| 24506/24506 [00:01<00:00, 14120.83it/s]
# Extracting Dataset Version Zip to TP26_detection_v2-1 in yolov11:: 100%|██████████| 2412/2412 [00:01<00:00, 2402.68it/s]
# <roboflow.core.dataset.Dataset object at 0x000002409F5874D0>
# {
#   "name": "TP26_detection_v2",
#   "type": "object-detection",
#   "version": "1",
#   "augmentation": {
#     "flip": {
#       "horizontal": true,
#       "vertical": true
#     },
#     "blur": {
#       "pixels": 0.5
#     },
#     "brightness": {
#       "percent": 20,
#       "brighten": true,
#       "darken": true
#     },
#     "exposure": {
#       "percent": 5
#     },
#     "image": {
#       "versions": 2
#     }
#   },
#   "created": 1774648151.73,
#   "preprocessing": {
#     "auto-orient": true
#   },
#   "splits": {
#     "valid": 106,
#     "test": 106,
#     "train": 988
#   },
#   "workspace": "hemorrhagesegmentation"
# }
# {
#   "name": "TP26_detection_v2",
#   "type": "object-detection",
#   "workspace": "hemorrhagesegmentation"
# }
# C:\Users\benko\Desktop\YOLO\TP26_detection_v2-1
