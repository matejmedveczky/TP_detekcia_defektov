# %%
#Tréning

from ultralytics import YOLO

model = YOLO("yolo11n.pt")

results = model.train(
    data="datasets/NEU-DET/data.yaml",
    epochs=3,
    imgsz=640,
    batch=16,
    project="runs/detect",
    name="neu_det",
    exist_ok=True
)
# Out:
# Ultralytics 8.4.21  Python-3.13.3 torch-2.10.0+cpu CPU (Intel Core i7-10750H 2.60GHz)
# ...

# %%
#Validácia po tréningu

from ultralytics import YOLO

model = YOLO("runs/detect/runs/detect/neu_det/weights/best.pt")
metrics = model.val(data="datasets/NEU-DET/data.yaml")

print("mAP50-95:", metrics.box.map)
print("mAP50:", metrics.box.map50)
print("Precision:", metrics.box.mp)
print("Recall:", metrics.box.mr)
# Out:
# Ultralytics 8.4.21  Python-3.13.3 torch-2.10.0+cpu CPU (Intel Core i7-10750H 2.60GHz)
# YOLO11n summary (fused): 101 layers, 2,583,322 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access  (ping: 0.20.3 ms, read: 78.848.2 MB/s, size: 16.3 KB)
# val: Scanning C:\Users\benko\OneDrive\Počítač\YOLO\datasets\NEU-DET\labels\val.cache... 359 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 359/359 71.7Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 23/23 1.7s/it 39.4s1.7ss
#                    all        359        853       0.46      0.569      0.482      0.212
#                crazing         60        162      0.298      0.228      0.226     0.0672
#              inclusion         71        159      0.538      0.635      0.586      0.255
#                patches         73        193      0.586       0.85       0.82       0.46
# ...

# %%
#Test na jednej fotke

from ultralytics import YOLO

model = YOLO("runs/detect/runs/detect/neu_det/weights/best.pt")

results = model.predict(
    source="datasets/NEU-DET/images/val/scratches_288.jpg",
    conf=0.25,
    save=True
)
# Out:
# image 1/1 C:\Users\benko\OneDrive\Pota\YOLO\datasets\NEU-DET\images\val\scratches_288.jpg: 640x640 1 scratches, 75.1ms
# Speed: 4.8ms preprocess, 75.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to C:\Users\benko\OneDrive\Pota\YOLO\runs\detect\predict6
