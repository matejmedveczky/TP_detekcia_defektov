# %%
#Výpis či je torch nainštalovaný aj pre grafiku a nie iba pre cpu

import torch
print(torch.__version__)
print(torch.cuda.is_available())
print(torch.cuda.device_count())
print(torch.cuda.get_device_name(0) if torch.cuda.is_available() else "GPU not found")
# Out:
# 2.11.0+cu128
# True
# 1
# NVIDIA GeForce RTX 5080

# %%
from ultralytics import YOLO

model = YOLO("yolo11n.pt")

results = model.train(
    data="TP26_detection-1/data.yaml",
    epochs=150,
    imgsz=512,
    batch=16,
    project="detectTP",
    name="yolo_tp_newest",
    device=0
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.25 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.21  Python-3.13.3 torch-2.10.0+cu128 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
# ...

# %%
#test na obrázkoch tp26_detection-1/test

from ultralytics import YOLO

model = YOLO("runs/detect/detectTP/yolo_tp_newest/weights/best.pt")

results = model.predict(
    source="TP26_detection-1/test/images",
    save=True,
    device=0,
    project="predictTP",
    name="predict_TP_newest",
    exist_ok=True
)
# Out:
# image 1/111 C:\Users\benko\Desktop\YOLO\TP26_detection-1\test\images\bad1_0001_png.rf.b674b26e9244a0e3f18d90396a211fd5.jpg: 512x512 1 scratch, 6.5ms
# image 2/111 C:\Users\benko\Desktop\YOLO\TP26_detection-1\test\images\bad1_0002_png.rf.d74181fa6dccd0fac05e4f6cfd31280b.jpg: 512x512 1 scratch, 6.6ms
# image 3/111 C:\Users\benko\Desktop\YOLO\TP26_detection-1\test\images\bad1_0003_png.rf.961edaa0cc8b9fca3ea39e60ff9b2bac.jpg: 512x512 2 scratchs, 4.7ms
# image 4/111 C:\Users\benko\Desktop\YOLO\TP26_detection-1\test\images\bad1_0004_png.rf.497d69e3784fee46d88c4ab00edc5c5f.jpg: 512x512 1 scratch, 5.0ms
# image 5/111 C:\Users\benko\Desktop\YOLO\TP26_detection-1\test\images\bad1_0005_png.rf.4bb5b55032321e2c9e1c42dc75eeea10.jpg: 512x512 3 scratchs, 4.1ms
# image 6/111 C:\Users\benko\Desktop\YOLO\TP26_detection-1\test\images\bad1_0006_png.rf.568f7b177475409260e7bf4538cb2e41.jpg: 512x512 1 scratch, 4.3ms
# ...
