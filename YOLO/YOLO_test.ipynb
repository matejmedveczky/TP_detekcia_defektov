# %%
import torch
from ultralytics import YOLO

model = YOLO("C:\\Users\\matej\\OneDrive\\Dokumenty\\STU FEI\\Ing\\TP\\runs\\detect\\detectTP\\yolo_metal-2\\weights\\best.pt")

results = model.val(
    data="TP26_detection_v2-3/data.yaml",
    # split="test"
    conf=0.15,
    project="nano",
    name="nano_valid",
)
# Out:
# Ultralytics 8.4.23  Python-3.13.7 torch-2.10.0+cpu CPU (AMD Ryzen 7 5700U with Radeon Graphics)
# YOLO11n summary (fused): 101 layers, 2,582,932 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access  (ping: 0.10.0 ms, read: 78.924.4 MB/s, size: 20.6 KB)
# val: Scanning C:\Users\matej\OneDrive\Dokumenty\STU FEI\Ing\TP\YOLO\TP26_detection_v2-3\valid\labels.cache... 112 images, 45 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 112/112 13.8Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.0s/it 7.0s1.1ss
#                    all        112        127      0.964      0.928      0.955      0.714
#                   burr         19         33       0.96       0.97      0.978      0.632
#        circular_cavity         26         49      0.995       0.98      0.994      0.773
#        excess_material         15         19      0.941      0.842      0.913      0.747
#                scratch         18         26       0.96       0.92      0.934      0.705
# Speed: 1.3ms preprocess, 54.6ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to C:\Users\matej\OneDrive\Dokumenty\STU FEI\Ing\TP\runs\detect\nano\nano_valid

# %%
import torch
from ultralytics import YOLO

model = YOLO("C:\\Users\\matej\\OneDrive\\Dokumenty\\STU FEI\\Ing\\TP\\runs\\detect\\detectTP\\yolo_metal-2\\weights\\best.pt")

results = model.predict(
    data="TP26_detection_v2-multi/data.yaml",
    # split="test",
    conf=0.15,
    project="nano",
    name="nano_valid",
)
