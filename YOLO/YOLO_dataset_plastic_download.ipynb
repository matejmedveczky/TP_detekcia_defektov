# %%
import os
from dotenv import load_dotenv
from roboflow import Roboflow

load_dotenv()
api_key = os.getenv("ROBOFLOW_API_KEY")

def download_dataset():
    rf = Roboflow(api_key="iu6ZV7FQa8wrgjPX8JeH")
    project = rf.workspace("hemorrhagesegmentation").project("tp26_plastic_v1")
    version = project.version(1)
    dataset = version.download("yolov11")

    return dataset, version, project

# %%
dataset, version, project = download_dataset()

print(dataset)
print(version)
print(project)

print(dataset.location)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in TP26_plastic_v1-1 to yolov11:: 100%|██████████| 38582/38582 [00:02<00:00, 16166.90it/s]
# Extracting Dataset Version Zip to TP26_plastic_v1-1 in yolov11:: 100%|██████████| 3927/3927 [00:01<00:00, 2660.27it/s]
# <roboflow.core.dataset.Dataset object at 0x000001F646AF74D0>
# {
#   "name": "TP26_plastic_v1",
#   "type": "object-detection",
#   "version": "1",
#   "augmentation": {
#     "image": {
#       "versions": 3
#     },
#     "flip": {
#       "horizontal": true,
#       "vertical": true
#     },
#     "rotate": {
#       "degrees": 15
#     },
#     "blur": {
#       "pixels": 0.5
#     },
#     "brightness": {
#       "percent": 15,
#       "brighten": true,
#       "darken": true
#     }
#   },
#   "created": 1776118700.114,
#   "preprocessing": {
#     "auto-orient": true
#   },
#   "splits": {
#     "valid": 123,
#     "test": 122,
#     "train": 1716
#   },
#   "workspace": "hemorrhagesegmentation"
# }
# {
#   "name": "TP26_plastic_v1",
#   "type": "object-detection",
#   "workspace": "hemorrhagesegmentation"
# }
# C:\Users\benko\Desktop\YOLO\TP26_plastic_v1-1
